# %%
import emoji
import random

def print_board(board):
   print("  1 2 3")
   j=1
   for i in board:
    print("%d|%s|" % (j,"|".join(i)))
    j+=1

def user_x(listA,board):
  while True:
    while True:
      row=int(input("Enter the row number you want:"))- 1
      col=int(input("Enter the column number you want:")) -1
      if row not in range(3) or col not in range(3):
        print("\033[1;31;47m")
        print("The coordinate you chose is Out of bounds, try again!!")
        print("\033[1;35;47m")
        continue
      else:
        if board[row][col] in {"O" , "X"} :
            print("\033[1;31;47m")
            print("The coordinate you chose is taken, try again!!")
            print("\033[1;35;47m")
            continue
        else:
           board[row][col]="X"
           print_board(board)
           break
    turn=9
    for  i in range(3):
      for j in range(3):
        if board[i][j] != " ":
          turn-=1

    if board[0][0] =="X"  and board[0][0]== board[0][1] and board[0][1]==board[0][2]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif board[1][0] =="X"  and board[1][0]== board[1][1] and board[1][1]==board[1][2]:
            print("\n!!! YOU WON !!!")
            break
    elif board[2][0] =="X"  and board[2][0]== board[2][1] and board[2][1]==board[2][2]:
            print("\n!!! YOU WON !!!")
            break
    elif board[0][0] =="X"  and board[0][0]== board[1][0] and board[1][0]==board[2][0]:
            print("\n!!! YOU WON !!!")
            break
    elif board[0][1] =="X"  and board[0][1]== board[1][1] and board[1][1]==board[2][1]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif board[0][2] =="X"  and board[0][2]== board[1][2] and board[1][2]==board[2][2]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif  board[0][0] =="X" and board[0][0] == board[1][1] and board[1][1]==board[2][2]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif  board[0][2] =="X" and  board[0][2] ==board[1][1] and board[1][1]==board[2][0]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif turn==0:
        print("\n!!!THE GAME IS TIED!!!"+emoji.emojize(":face_blowing_a_kiss:"))
        break





    while True:
      row=random.choice(listA)
      col=random.choice(listA)
      if board[row][col] in {"O" , "X"}:
        row=random.choice(listA)
        col=random.choice(listA)
      else:
        board[row][col]="O"
        print_board(board)
        break
    turn=9
    for  i in range(3):
      for j in range(3):
        if board[i][j] != " ":
          turn-=1


    if board[0][0] =="O"  and board[0][0]== board[0][1] and board[0][1]==board[0][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif board[1][0] =="O"  and board[1][0]== board[1][1] and board[1][1]==board[1][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif board[2][0] =="O"  and board[2][0]== board[2][1] and board[2][1]==board[2][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif board[0][0] =="O"  and board[0][0]== board[1][0] and board[1][0]==board[2][0]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif board[0][1] =="O"  and board[0][1]== board[1][1] and board[1][1]==board[2][1]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif board[0][2] =="O"  and board[0][2]== board[1][2] and board[1][2]==board[2][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif  board[0][0] =="O" and board[0][0] == board[1][1] and board[1][1]==board[2][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif  board[0][2] =="O" and  board[0][2] ==board[1][1] and board[1][1]==board[2][0]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif turn==0:
        print("\n!!!THE GAME IS TIED!!!"+emoji.emojize(":winking_face_with_tongue:"))
        break

def user_o(listA,board):
  while True:
    while True:
      row=random.choice(listA)
      col=random.choice(listA)
      if board[row][col] in {"O" , "X"}:
         continue
      else:
        board[row][col]="X"
        print_board(board)
        break
    turn=9
    for  i in range(3):
      for j in range(3):
        if board[i][j] != " ":
          turn-=1

    if board[0][0] =="X"  and board[0][0]== board[0][1] and board[0][1]==board[0][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif board[1][0] =="X"  and board[1][0]== board[1][1] and board[1][1]==board[1][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif board[2][0] =="X"  and board[2][0]== board[2][1] and board[2][1]==board[2][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif board[0][0] =="X"  and board[0][0]== board[1][0] and board[1][0]==board[2][0]:
            print("\n!!! AI WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif board[0][1] =="X"  and board[0][1]== board[1][1] and board[1][1]==board[2][1]:
            print("\n!!! AI WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif board[0][2] =="X"  and board[0][2]== board[1][2] and board[1][2]==board[2][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif  board[0][0] =="X" and board[0][0] == board[1][1] and board[1][1]==board[2][2]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif  board[0][2] =="X" and  board[0][2] ==board[1][1] and board[1][1]==board[2][0]:
            print("\n!!! AI WON !!!"+emoji.emojize(":winking_face_with_tongue:"))
            break
    elif turn==0:
            print("\n!!!THE GAME IS TIED!!!"+emoji.emojize(":winking_face_with_tongue:"))
            break

    #user start

    while True:
      row=int(input("Enter the row number you want:"))- 1
      col=int(input("Enter the column number you want:")) -1
      if row not in range(3) or col not in range(3):
        print("\033[1;31;47m")
        print("The coordinate you chose is Out of bounds, try again!!")
        print("\033[1;35;47m")
        continue
      else:
        if board[row][col] in {"O" , "X"} :
            print("\033[1;31;47m")
            print("The coordinate you chose is taken, try again!!")
            print("\033[1;35;47m")
            continue
        else:
           board[row][col]="O"
           print_board(board)
           break
    turn=9
    for  i in range(3):
      for j in range(3):
        if board[i][j] != " ":
          turn-=1


    if board[0][0] =="O"  and board[0][0]== board[0][1] and board[0][1]==board[0][2]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif board[1][0] =="O"  and board[1][0]== board[1][1] and board[1][1]==board[1][2]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif board[2][0] =="O"  and board[2][0]== board[2][1] and board[2][1]==board[2][2]:
            print("\n!!! YOU WON !!!")
            break
    elif board[0][0] =="O"  and board[0][0]== board[1][0] and board[1][0]==board[2][0]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif board[0][1] =="O"  and board[0][1]== board[1][1] and board[1][1]==board[2][1]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif board[0][2] =="O"  and board[0][2]== board[1][2] and board[1][2]==board[2][2]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif  board[0][0] =="O" and board[0][0] == board[1][1] and board[1][1]==board[2][2]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif  board[0][2] =="O" and  board[0][2] ==board[1][1] and board[1][1]==board[2][0]:
            print("\n!!! YOU WON !!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break
    elif turn==0:
            print("\n!!!THE GAME IS TIED!!!"+emoji.emojize(":face_blowing_a_kiss:"))
            break


print("\033[1;35;47m")
print("Welcome to the tic tac toe game".upper()+emoji.emojize(":grinning_face_with_big_eyes:"))
print("let's enjoy playing together!!".upper()+emoji.emojize(":winking_face_with_tongue:"))
print("\n")
user_choice=input("Would you rather play with X or O? ".upper())
print("\n")
board=[[" "]* 3 for _ in range(3)]
listA = [0, 1, 2]

if user_choice =='X' or user_choice =='x':
  user_x(listA,board)

elif user_choice =='O' or user_choice =='o':
  user_o(listA,board)
# Out:
# WELCOME TO THE TIC TAC TOE GAME😃
# LET'S ENJOY PLAYING TOGETHER!!😜
#
#
# WOULD YOU RATHER PLAY WITH X OR O? x
#
#
# Enter the row number you want:3
# Enter the column number you want:3
#   1 2 3
# 1| | | |
# 2| | | |
# 3| | |X|
#   1 2 3
# 1| | | |
# 2| | |O|
# 3| | |X|
# Enter the row number you want:3
# Enter the column number you want:1
#   1 2 3
# 1| | | |
# 2| | |O|
# 3|X| |X|
#   1 2 3
# 1| | | |
# 2| |O|O|
# 3|X| |X|
# Enter the row number you want:1
# Enter the column number you want:2
#   1 2 3
# 1| |X| |
# 2| |O|O|
# 3|X| |X|
#   1 2 3
# 1| |X| |
# 2| |O|O|
# 3|X|O|X|
# Enter the row number you want:1
# Enter the column number you want:3
#   1 2 3
# 1| |X|X|
# 2| |O|O|
# 3|X|O|X|
#   1 2 3
# 1|O|X|X|
# 2| |O|O|
# 3|X|O|X|
# Enter the row number you want:2
# Enter the column number you want:1
#   1 2 3
# 1|O|X|X|
# 2|X|O|O|
# 3|X|O|X|
#
# !!!THE GAME IS TIED!!!😘
